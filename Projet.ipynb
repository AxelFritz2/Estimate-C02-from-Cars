# %%
import pandas as pd
import sys 
sys.path.append("./src/")

import analyse_exploratoire as ae

# %%
df = pd.read_csv('data/train.csv')
# Out:
# C:\Users\baheu\AppData\Local\Temp\ipykernel_33212\4207432485.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/train.csv')

# %%
df.head()
# Out:
#    ID Country                       VFN          Mp               Mh  \
# 0   0      DE  IP-C519_2022_00008-WF0-1        FORD  FORD WERKE GMBH
# 1   1      FR  IP-MQB27ZZ_A2_0529-WVW-1  VOLKSWAGEN       VOLKSWAGEN
# 2   2      FR  IP-MQB27ZZ_A1_0533-WVW-1  VOLKSWAGEN       VOLKSWAGEN
# 3   3      DE       IP-04-U5Y-2018-1137         KIA     KIA SLOVAKIA
# 4   4      FR  IP-MQB27ZZ_B2_0534-WVW-1  VOLKSWAGEN       VOLKSWAGEN
#
#                 Man  MMS                  Tan    T       Va  ... z (Wh/km)  \
# 0   FORD WERKE GMBH  NaN  e13*2007/46*1911*15  DEH  R0DB1NX  ...       NaN
# 1     VOLKSWAGEN AG  NaN   e1*2007/46*1783*29   AW   ABDLAC  ...       NaN
# 2     VOLKSWAGEN AG  NaN   e1*2007/46*1783*29   AW   ABDLAC  ...       NaN
# 3  KIA SLOVAKIA SRO  NaN   e4*2007/46*1299*18   CD    BAP71  ...       NaN
# 4     VOLKSWAGEN AG  NaN   e1*2007/46*1783*29   AW   ABDLAA  ...       NaN
#
#           IT Ernedc (g/km) Erwltp (g/km)  De  Vf  Status  \
# 0  e13 32 37           NaN          2.30 NaN NaN       P
# 1      e1 29           NaN          1.14 NaN NaN       P
# 2      e1 29           NaN          1.14 NaN NaN       P
# 3      e4 28           NaN          0.80 NaN NaN       P
# 4      e1 29           NaN          1.14 NaN NaN       P
#
#    Date of registration  Fuel consumption   Electric range (km)
# 0            2022-08-29                5.6                  NaN
# 1            2022-02-22                5.5                  NaN
# 2            2022-03-26                5.6                  NaN
# 3            2022-09-01                6.8                  NaN
# 4            2022-01-21                5.9                  NaN
#
# [5 rows x 37 columns]

# %%
analyse = ae.DataAnalysis(df)
col_numericals, col_categorical = analyse.get_numericals_categoricals()

print(f'liste des colonnes numériques {col_numericals}')
print(f'liste des colonnes catégorielles {col_categorical}')
# Out:
# liste des colonnes numériques ['ID', 'MMS', 'r', 'm (kg)', 'Mt', 'Enedc (g/km)', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'ec (cm3)', 'ep (KW)', 'z (Wh/km)', 'Ernedc (g/km)', 'Erwltp (g/km)', 'De', 'Vf', 'Fuel consumption ', 'Electric range (km)']
# liste des colonnes catégorielles ['Country', 'VFN', 'Mp', 'Mh', 'Man', 'Tan', 'T', 'Va', 'Ve', 'Mk', 'Cn', 'Ct', 'Cr', 'Ft', 'Fm', 'IT', 'Status', 'Date of registration']

# %%
analyse.plot_marginal_distributions(col_numericals)
# Out:
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
# C:\Users\baheu\Documents\M2 MoSEF\Data_mining\Challenge_Kaggle_Mosef\./src\analyse_exploratoire.py:46: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(ax=ax, data=self.df[variable], legend=None, shade=True)
